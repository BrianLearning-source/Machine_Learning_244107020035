# %% [markdown]
# LAB ASSIGNMENT

# %% [markdown]
# # Assignment Description
#
# In this practical assignment you will employ the "Wisconsin Breast Cancer" dataset. The dataset comprises 569 records used for diagnosing cancer types Malignant (M) and Benign (B). Your task is to
#
# 1. Differentiate between variables that are usable and variables that are not usable.
#
# 2. Perform encoding on the "diagnosis" column.
#
# 3. Perform standardization on all columns that possess numerical values.

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, StandardScaler
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('wbc.csv')

df.head()
# Out:
#          id diagnosis  ...  fractal_dimension_worst  Unnamed: 32
# 0    842302         M  ...                  0.11890          NaN
# 1    842517         M  ...                  0.08902          NaN
# 2  84300903         M  ...                  0.08758          NaN
# 3  84348301         M  ...                  0.17300          NaN
# 4  84358402         M  ...                  0.07678          NaN
#
# [5 rows x 33 columns]

# %%
df.head(60)
# Out:
#           id diagnosis  ...  fractal_dimension_worst  Unnamed: 32
# 0     842302         M  ...                  0.11890          NaN
# 1     842517         M  ...                  0.08902          NaN
# 2   84300903         M  ...                  0.08758          NaN
# 3   84348301         M  ...                  0.17300          NaN
# 4   84358402         M  ...                  0.07678          NaN
# 5     843786         M  ...                  0.12440          NaN
# 6     844359         M  ...                  0.08368          NaN
# 7   84458202         M  ...                  0.11510          NaN
# 8     844981         M  ...                  0.10720          NaN
# 9   84501001         M  ...                  0.20750          NaN
# 10    845636         M  ...                  0.08452          NaN
# 11  84610002         M  ...                  0.10480          NaN
# 12    846226         M  ...                  0.10230          NaN
# ...

# %% [markdown]
# # ANSWER 1  (Differentiate between variables that are usable and variables that are not usable.)
#
# *Usable Variable :*
# - perimeter_mean
# - concavity_mean
# - radius_se
# - perimeter_se
# - symmetry_worst
# - compactness_worst
# - perimeter_worst
#
# *Not Usable Variable :*
# - radius_mean
# - texture_mean
# - area_mean
# - smoothness_mean
# - compactness_mean
# - concave points_mean
# - symmetry_mean
# - fractal_dimension_mean
# - texture_se
# - area_se
# - smoothness_se
# - compactness_se
# - concavity_se
# - concave points_se
# - symmetry_se
# - fractal_dimension_se
# - radius_worst
# - texture_worst
# - area_worst
# - smoothness_worst
# - concavity_worst
# - concave points_worst
# - fractal_dimension_worst
# - Unnamed: 32

# %%
df = df[['diagnosis', 'perimeter_mean', 'concavity_mean', 'radius_se', 'perimeter_se', 'symmetry_worst', 'compactness_worst', 'perimeter_worst' ]]
df.head()
# Out:
#   diagnosis  perimeter_mean  ...  compactness_worst  perimeter_worst
# 0         M          122.80  ...             0.6656           184.60
# 1         M          132.90  ...             0.1866           158.80
# 2         M          130.00  ...             0.4245           152.50
# 3         M           77.58  ...             0.8663            98.87
# 4         M          135.10  ...             0.2050           152.20
#
# [5 rows x 8 columns]

# %% [markdown]
# # ANSWER 2 (Perform encoding on the "diagnosis" column)

# %%
le = LabelEncoder()
df['diagnosis'] = le.fit_transform(df['diagnosis'])

# %%
df.head()
# Out:
#    diagnosis  perimeter_mean  ...  compactness_worst  perimeter_worst
# 0          1          122.80  ...             0.6656           184.60
# 1          1          132.90  ...             0.1866           158.80
# 2          1          130.00  ...             0.4245           152.50
# 3          1           77.58  ...             0.8663            98.87
# 4          1          135.10  ...             0.2050           152.20
#
# [5 rows x 8 columns]

# %% [markdown]
# # ANSWER 3 (Perform standardization on all columns that possess numerical values)

# %%
std = StandardScaler()

num_cols = df.select_dtypes(include=['number']).columns
df[num_cols] = std.fit_transform(df[num_cols])
df.head()
# Out:
#    diagnosis  perimeter_mean  ...  compactness_worst  perimeter_worst
# 0   1.297676        1.269934  ...           2.616665         2.303601
# 1   1.297676        1.685955  ...          -0.430444         1.535126
# 2   1.297676        1.566503  ...           1.082932         1.347475
# 3   1.297676       -0.592687  ...           3.893397        -0.249939
# 4   1.297676        1.776573  ...          -0.313395         1.338539
#
# [5 rows x 8 columns]
