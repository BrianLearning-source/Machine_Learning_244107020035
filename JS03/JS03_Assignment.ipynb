# %% [markdown]
# Lab Assignment

# %% [markdown]
# Assignment Description
#
# In this practical assignment you will employ the "Wisconsin Breast Canser" dataset. The dataset comprises 569 records used for diagnosing cancer type Malignant (M) and Benign (B). Your task is to
#
#
# 1. Differentiate between variables that are usable and variables that are not usable.
#
# 2. Perform encoding on the "diagnosis" column.
#
# 3. Perform standardization on all columns that possess numerical values.
#
# 4. Perform the feature selection process. You may use SelectKBest.
#
# 5. Conduct the testing process using a Logistic Regression model as in practical session 1.
#
# 6. You may employ a model pipeline to facilitate your work.
#
# 7. Based on your analysis results, how many optimal features can be used? Which features are they?

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, StandardScaler
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('wbc.csv')

df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.head(60)
# Out:
#           id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0     842302         M       17.990         10.38          122.80     1001.0
# 1     842517         M       20.570         17.77          132.90     1326.0
# 2   84300903         M       19.690         21.25          130.00     1203.0
# 3   84348301         M       11.420         20.38           77.58      386.1
# 4   84358402         M       20.290         14.34          135.10     1297.0
# 5     843786         M       12.450         15.70           82.57      477.1
# 6     844359         M       18.250         19.98          119.60     1040.0
# 7   84458202         M       13.710         20.83           90.20      577.9
# 8     844981         M       13.000         21.82           87.50      519.8
# 9   84501001         M       12.460         24.04           83.97      475.9
# 10    845636         M       16.020         23.24          102.70      797.8
# ...

# %% [markdown]
# # ANSWER 1  (Differentiate between variables that are usable and variables that are not usable.)
#
# *Usable Variable :*
# - perimeter_mean
# - concavity_mean
# - radius_se
# - perimeter_se
# - symmetry_worst
# - compactness_worst
# - perimeter_worst
#
# *Not Usable Variable :*
# - radius_mean
# - texture_mean
# - area_mean
# - smoothness_mean
# - compactness_mean
# - concave points_mean
# - symmetry_mean
# - fractal_dimension_mean
# - texture_se
# - area_se
# - smoothness_se
# - compactness_se
# - concavity_se
# - concave points_se
# - symmetry_se
# - fractal_dimension_se
# - radius_worst
# - texture_worst
# - area_worst
# - smoothness_worst
# - concavity_worst
# - concave points_worst
# - fractal_dimension_worst
# - Unnamed: 32

# %%
df = df[['diagnosis', 'perimeter_mean', 'concavity_mean', 'radius_se', 'perimeter_se', 'symmetry_worst', 'compactness_worst', 'perimeter_worst' ]]
df.head()
# Out:
#   diagnosis  perimeter_mean  concavity_mean  radius_se  perimeter_se  \
# 0         M          122.80          0.3001     1.0950         8.589
# 1         M          132.90          0.0869     0.5435         3.398
# 2         M          130.00          0.1974     0.7456         4.585
# 3         M           77.58          0.2414     0.4956         3.445
# 4         M          135.10          0.1980     0.7572         5.438
#
#    symmetry_worst  compactness_worst  perimeter_worst
# 0          0.4601             0.6656           184.60
# 1          0.2750             0.1866           158.80
# 2          0.3613             0.4245           152.50
# 3          0.6638             0.8663            98.87
# 4          0.2364             0.2050           152.20

# %% [markdown]
# # ANSWER 2 (Perform encoding on the "diagnosis" column)

# %%
le = LabelEncoder()
df['diagnosis'] = le.fit_transform(df['diagnosis'])

# %%
df.head()
# Out:
#    diagnosis  perimeter_mean  concavity_mean  radius_se  perimeter_se  \
# 0          1          122.80          0.3001     1.0950         8.589
# 1          1          132.90          0.0869     0.5435         3.398
# 2          1          130.00          0.1974     0.7456         4.585
# 3          1           77.58          0.2414     0.4956         3.445
# 4          1          135.10          0.1980     0.7572         5.438
#
#    symmetry_worst  compactness_worst  perimeter_worst
# 0          0.4601             0.6656           184.60
# 1          0.2750             0.1866           158.80
# 2          0.3613             0.4245           152.50
# 3          0.6638             0.8663            98.87
# 4          0.2364             0.2050           152.20

# %% [markdown]
# # ANSWER 3 (Perform standardization on all columns that possess numerical values)

# %%
std = StandardScaler()

num_cols = df.select_dtypes(include=['number']).columns
df[num_cols] = std.fit_transform(df[num_cols])
df.head()
# Out:
#    diagnosis  perimeter_mean  concavity_mean  radius_se  perimeter_se  \
# 0   1.297676        1.269934        2.652874   2.489734      2.833031
# 1   1.297676        1.685955       -0.023846   0.499255      0.263327
# 2   1.297676        1.566503        1.363478   1.228676      0.850928
# 3   1.297676       -0.592687        1.915897   0.326373      0.286593
# 4   1.297676        1.776573        1.371011   1.270543      1.273189
#
#    symmetry_worst  compactness_worst  perimeter_worst
# 0        2.750622           2.616665         2.303601
# 1       -0.243890          -0.430444         1.535126
# 2        1.152255           1.082932         1.347475
# 3        6.046041           3.893397        -0.249939
# 4       -0.868353          -0.313395         1.338539

# %% [markdown]
# # ANSWER 4 (Perform the feature selection process. You may use SelectKBest.)
